# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-dev python3.10-distutils -y
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --config python3
# when prompted, choose the python3.10 option (usually option 1 or 2)
# !python3 -V
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3 get-pip.py
# !pip install nibabel einops tensorboardX
# !pip install monai==0.8.0 numpy==1.23.5
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,923 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
import sys
# Adjust this path to your actual model location on your drive
import sys
sys.path.append('/content/drive/MyDrive/UNETR Project/BTCV/networks')

import torch
from typing import Tuple, Union

# Import your modified UNETR class (make sure it's named UNETR in the file)
from Unter_with_self_attention import UNETR

# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Model init with parameters matching your setup
model = UNETR(
    in_channels=1,
    out_channels=14,
    img_size=(96, 96, 96),  # Must be divisible by patch size (16)
    feature_size=16,
    hidden_size=768,
    mlp_dim=3072,
    num_heads=12,
    pos_embed="perceptron",
    norm_name="instance",
    conv_block=True,
    res_block=True,
    dropout_rate=0.0,
).to(device)

# Dummy input tensor: batch size 1, channels 1, 96x96x96 volume
input_tensor = torch.randn(1, 1, 96, 96, 96).to(device)

# Forward pass
output = model(input_tensor)

print("Output shape:", output.shape)
# Expected: [1, 14, 96, 96, 96] (batch, out_channels, D, H, W)
# Out:
# /usr/local/lib/python3.11/dist-packages/cupyx/scipy/sparse/_base.py:10: UserWarning: A NumPy version >=1.25.2 and <2.6.0 is required for this version of SciPy (detected version 1.23.5)
#   import scipy.sparse as _sparse
# Output shape: torch.Size([1, 14, 96, 96, 96])

# %%
# !ls /content/drive/MyDrive/'UNETR Project'/BTCV/networks/
# Out:
# __init__.py  SelfAttention3D.py    unetr.py
# __pycache__  test_attention.ipynb  Unter_with_self_attention.py
